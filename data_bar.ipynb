# %%
# import drive and files in google colaboratory
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import os module
import numpy as np
data = "/content/drive/MyDrive/Art/Images/Images"
import os 
ldseg=np.array(os.listdir(data))
print(ldseg)
# Out:
# ['Chandra Sarkar' 'Mahatab Rashid' 'TarTin' 'Zarin' 'Injamamul Adittya'
#  'Farjan Shahriar Abeg' 'The Panicked Architect' 'The Bathroom Artist'
#  'Teabag Stories' 'Salman Sakib' 'Nycto' 'Nishat Binte Monsur' 'Inksmith'
#  'DarkaakArts' 'Icecream Stick Art' 'resized']

# %%
artist = []
artCount = []

for foldername in ldseg:
  if foldername!="resized":
    filespath = data + "/" + foldername +"/"
    print(foldername)
    artist.append(foldername)
    imagelist = np.array(os.listdir(filespath))
    print(len(imagelist))
    artCount.append(len(imagelist))

print(artist)
print(artCount)
# Out:
# Chandra Sarkar
# 34
# Mahatab Rashid
# 28
# TarTin
# 20
# Zarin
# 61
# Injamamul Adittya
# 42
# Farjan Shahriar Abeg
# 45
# The Panicked Architect
# 30
# The Bathroom Artist
# 46
# Teabag Stories
# 140
# Salman Sakib
# 53
# Nycto
# 54
# Nishat Binte Monsur
# 39
# Inksmith
# 45
# DarkaakArts
# 66
# Icecream Stick Art
# 16
# ['Chandra Sarkar', 'Mahatab Rashid', 'TarTin', 'Zarin', 'Injamamul Adittya', 'Farjan Shahriar Abeg', 'The Panicked Architect', 'The Bathroom Artist', 'Teabag Stories', 'Salman Sakib', 'Nycto', 'Nishat Binte Monsur', 'Inksmith', 'DarkaakArts', 'Icecream Stick Art']
# [34, 28, 20, 61, 42, 45, 30, 46, 140, 53, 54, 39, 45, 66, 16]

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))

# Horizontal Bar Plot
ax.barh(artist, artCount)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
	ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
		linestyle ='-.', linewidth = 0.5,
		alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
	plt.text(i.get_width()+0.2, i.get_y()+0.5,
			str(round((i.get_width()), 2)),
			fontsize = 10, fontweight ='bold',
			color ='grey')

# Add Plot Title
ax.set_title('Artists and Art Count In The Dataset',
			loc ='left', )

# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
		color ='grey', ha ='right', va ='bottom',
		alpha = 0.7)

# Show Plot
plt.show()
